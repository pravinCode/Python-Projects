# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the Excel file
file_path = 'phonepe-pulse_raw-data.xlsx'

# %%
# Q-1.1.1 Load the State_txn and Users dataset and display its first 5 rows. 
import pandas as pd
state_txn_users = pd.read_excel(file_path, sheet_name=0)
print("First 5 rows of State_Txn and Users dataset:")
state_txn_users.head(5)
# Out:
# First 5 rows of State_Txn and Users dataset:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0

# %%
# Q-1.1.2 Load the State_TxnSplit dataset and display its bottom 10 rows. 
state_txn_split = pd.read_excel(file_path, sheet_name=1)
print("Bottom 10 rows of State_TxnSplit dataset:")
state_txn_split.tail(10)
# Out:
# Bottom 10 rows of State_TxnSplit dataset:
#             State  Year  Quarter          Transaction Type  Transactions  \
# 2504  West Bengal  2021        1     Peer-to-peer payments      53869075
# 2505  West Bengal  2021        1         Merchant payments      37143701
# 2506  West Bengal  2021        1  Recharge & bill payments      26673733
# 2507  West Bengal  2021        1        Financial Services        166727
# 2508  West Bengal  2021        1                    Others        400816
# 2509  West Bengal  2021        2     Peer-to-peer payments      64661051
# 2510  West Bengal  2021        2         Merchant payments      41696787
# 2511  West Bengal  2021        2  Recharge & bill payments      34799709
# 2512  West Bengal  2021        2        Financial Services        190537
# 2513  West Bengal  2021        2                    Others        549353
#
#       Amount (INR)    ATV (INR)
# 2504  2.022402e+11  3754.292226
# 2505  2.891834e+10   778.553104
# ...

# %%
# Q-1.1.3 Load the State_DeviceData dataset and display 10 rows from the middle of the dataset. 
state_device_data = pd.read_excel(file_path, sheet_name=2)
middle_index = len(state_device_data) // 2
print("10 rows from the middle of State_DeviceData dataset:")
state_device_data.iloc[middle_index:middle_index + 10]
# Out:
# 10 rows from the middle of State_DeviceData dataset:
#             State  Year  Quarter    Brand  Registered Users  Percentage
# 2772  Lakshadweep  2018        1  Samsung               102    0.203593
# 2773  Lakshadweep  2018        1   Xiaomi               100    0.199601
# 2774  Lakshadweep  2018        1     Vivo                67    0.133733
# 2775  Lakshadweep  2018        1     Oppo                56    0.111776
# 2776  Lakshadweep  2018        1   Huawei                25    0.049900
# 2777  Lakshadweep  2018        1  OnePlus                22    0.043912
# 2778  Lakshadweep  2018        1    Apple                20    0.039920
# 2779  Lakshadweep  2018        1   Realme                20    0.039920
# 2780  Lakshadweep  2018        1   Gionee                12    0.023952
# 2781  Lakshadweep  2018        1  COOLPAD                10    0.019960

# %%
# Q-1.1.4 Load the District_Txn and Users dataset and display its first 10 rows and last 10 rows. 
district_txn_and_users = pd.read_excel(file_path, sheet_name=3)
district_txn_and_users_top_bottom = pd.concat([district_txn_and_users.head(10), district_txn_and_users.tail(10)])
print("First 10 rows and Last 10 rows of District_Txn and Users dataset:")
district_txn_and_users_top_bottom
# Out:
# First 10 rows and Bottom 10 rows of District_Txn and Users dataset:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# 5      Andaman & Nicobar Islands  2018        2               South Andaman
# 6      Andaman & Nicobar Islands  2018        3                    Nicobars
# 7      Andaman & Nicobar Islands  2018        3    North And Middle Andaman
# 8      Andaman & Nicobar Islands  2018        3               South Andaman
# 9      Andaman & Nicobar Islands  2018        4                    Nicobars
# ...

# %%
# Q-1.1.5 Load the District Demographics dataset and display every 10th row.
district_demographics = pd.read_excel(file_path, sheet_name=4)
print("Every 10th row of District Demographics dataset:")
district_demographics.iloc[::10]
# Out:
# Every 10th row of District Demographics dataset:
#                  State       District   Headquarters  Population  \
# 0       Andhra Pradesh      Anantapur      Anantapur     4083315
# 10      Andhra Pradesh  Visakhapatnam  Visakhapatnam     4288113
# 20   Arunachal Pradesh      Lepa Rada          Basar           0
# 30   Arunachal Pradesh          Siang         Pangin       31920
# 40               Assam        Barpeta        Barpeta     1693622
# ..                 ...            ...            ...         ...
# 700         Chandigarh     Chandigarh     Chandigarh     1055450
# 710    Jammu & Kashmir          Jammu          Jammu     1526406
# 720    Jammu & Kashmir          Samba          Samba      318611
# 730              Delhi    North Delhi   Sadar Bazaar      887978
# 740         Puducherry     Puducherry    Pondicherry      950289
#
#      Area (sq km)  Density  Code Alternate Name
# 0         19130.0      213  AP01      Anantapur
# ...

# %%
# Q1.2.2 Display data types of each column in each dataset
#(dataset1)
print("Data types for State_Txn and Users dataset:")
state_txn_users.dtypes
# Out:
# Data types for State_Txn and Users dataset:
# State                object
# Year                  int64
# Quarter               int64
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
# Q1.2.2 (dataset2)
print("Data types for State_TxnSplit dataset:")
state_txn_split.dtypes
# Out:
# Data types for State_TxnSplit dataset:
# State                object
# Year                  int64
# Quarter               int64
# Transaction Type     object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# dtype: object

# %%
# Q1.2.2  (dataset3)
print("Data types for State_DeviceData dataset:")
state_device_data.dtypes
# Out:
# Data types for State_DeviceData dataset:
# State                object
# Year                  int64
# Quarter               int64
# Brand                object
# Registered Users      int64
# Percentage          float64
# dtype: object

# %%
# Q1.2.2  (dataset4)
print("Data types for District_Txn and Users dataset:")
district_txn_and_users.dtypes
# Out:
# Data types for District_Txn and Users dataset:
# State                object
# Year                  int64
# Quarter               int64
# District             object
# Code                 object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
# Q1.2.2 (dataset5)
print("Data types for District Demographics dataset:")
district_demographics.dtypes
# Out:
# Data types for District Demographics dataset:
# State              object
# District           object
# Headquarters       object
# Population          int64
# Area (sq km)      float64
# Density             int64
# Code               object
# Alternate Name     object
# dtype: object

# %%
# Q1.2.1 Display summary statistics for numerical columns in each dataset
#(dataset1)
print("Summary statistics for State_Txn and Users dataset:")
columns_to_exclude= ["Year", "Quarter"]
(state_txn_users.select_dtypes(include='number').drop(columns_to_exclude, axis=1).describe()).round(2)
# Out:
# Summary statistics for State_Txn and Users dataset:
#        Transactions  Amount (INR)  ATV (INR)  Registered Users     App Opens
# count  5.040000e+02  5.030000e+02     504.00            504.00  5.040000e+02
# mean   4.074000e+07  7.083332e+10    1993.47        4777500.89  9.774471e+07
# std    8.228714e+07  1.440902e+11     607.46        6644495.72  2.042376e+08
# min    7.780000e+02  1.928611e+06       0.00            501.00  0.000000e+00
# 25%    5.925578e+05  1.167157e+09    1598.91         157420.25  0.000000e+00
# 50%    6.217487e+06  1.051605e+10    1861.38        1747914.00  2.930574e+06
# 75%    4.363675e+07  6.947045e+10    2259.09        7320945.25  8.615022e+07
# max    5.736165e+08  1.027958e+12    3938.73       39664697.00  1.208084e+09

# %%
# Q1.2.1 (dataset2)
print("Summary statistics for State_TxnSplit dataset:")
columns_to_exclude= ["Year", "Quarter"]
(state_txn_split.select_dtypes(include='number').drop(columns_to_exclude, axis=1).describe()).round(2)
# Out:
# Summary statistics for State_TxnSplit dataset:
#        Transactions  Amount (INR)  ATV (INR)
# count  2.514000e+03  2.514000e+03    2514.00
# mean   8.167446e+06  1.443978e+10    1349.93
# std    2.423645e+07  5.995054e+10    1534.87
# min    2.000000e+00  3.440000e+01      17.20
# 25%    2.788075e+04  1.762412e+07     385.74
# 50%    2.687980e+05  1.901189e+08     720.94
# 75%    3.683230e+06  2.661248e+09    1352.79
# max    2.795990e+08  8.721520e+11    7767.54

# %%
# Q1.2.1 (dataset3)
print("Summary statistics for State_DeviceData dataset:")
columns_to_exclude= ["Year", "Quarter"]
(state_device_data.select_dtypes(include='number').drop(columns_to_exclude, axis=1).describe()).round(2)
# Out:
# Summary statistics for State_DeviceData dataset:
#        Registered Users  Percentage
# count           5544.00     5544.00
# mean          434318.26        0.09
# std           905606.95        0.08
# min               10.00        0.01
# 25%             8055.75        0.02
# 50%            74422.50        0.06
# 75%           397887.50        0.14
# max          9764252.00        0.48

# %%
# Q1.2.1 (dataset4)
print("Summary statistics for District_Txn and Users dataset:")
columns_to_exclude= ["Year", "Quarter"]
(district_txn_and_users.select_dtypes(include='number').drop(columns_to_exclude, axis=1).describe()).round(2)
# Out:
# Summary statistics for District_Txn and Users dataset:
#        Transactions  Amount (INR)  ATV (INR)  Registered Users     App Opens
# count  1.024800e+04  1.024800e+04   10244.00          10248.00  1.024800e+04
# mean   2.003607e+06  3.542311e+09    1909.80         234959.06  4.807117e+06
# std    9.613466e+06  1.473154e+10     600.94         460597.83  1.562541e+07
# min    0.000000e+00  0.000000e+00      84.94             22.00  0.000000e+00
# 25%    1.031418e+05  1.756668e+08    1554.59          36195.50  0.000000e+00
# 50%    3.763065e+05  6.784562e+08    1863.14         106764.00  6.403025e+05
# 75%    1.272815e+06  2.377256e+09    2203.08         257316.50  4.346320e+06
# max    3.487128e+08  4.444224e+11   11209.98       10604609.00  5.544197e+08

# %%
# Q1.2.1 (dataset5)
print("Summary statistics for District Demographics dataset:")
(district_demographics.select_dtypes(include='number').describe()).round(2)
# Out:
# Summary statistics for District Demographics dataset:
#         Population  Area (sq km)   Density
# count       742.00        742.00    742.00
# mean    1668554.61       4395.37    838.51
# std     1458849.18       4254.68   2754.41
# min           0.00          0.00      0.00
# 25%      653081.50       2039.75    198.00
# 50%     1322359.00       3402.50    353.00
# 75%     2297440.00       5432.75    686.25
# max    10082852.00      45652.00  36155.00

# %%
# Q-1.3.1
# Identify missing value for dataset1
print("Missing values in State_Txn and Users dataset:")
state_txn_users_missing_value = state_txn_users.isna().sum()
state_txn_users_missing_value
# Out:
# Missing values in State_Txn and Users dataset:
# State               0
# Year                0
# Quarter             0
# Transactions        0
# Amount (INR)        1
# ATV (INR)           0
# Registered Users    0
# App Opens           0
# dtype: int64

# %%
# Q-1.3.1
# Identify missing value for dataset2
print("Missing values in State_TxnSplit dataset:")
state_txn_split_missing_value = state_txn_split.isna().sum()
state_txn_split_missing_value
# Out:
# Missing values in State_TxnSplit dataset:
# State               0
# Year                0
# Quarter             0
# Transaction Type    0
# Transactions        0
# Amount (INR)        0
# ATV (INR)           0
# dtype: int64

# %%
# Q-1.3.1
# Identify missing value for dataset3
print("Missing values in State_DeviceData dataset:")
state_device_data_missing_value = state_device_data.isna().sum()
state_device_data_missing_value
# Out:
# Missing values in State_DeviceData dataset:
# State               0
# Year                0
# Quarter             0
# Brand               0
# Registered Users    0
# Percentage          0
# dtype: int64

# %%
# Q-1.3.1
# Identify missing value for dataset4
print("Missing values in District_Txn and Users dataset:")
district_txn_and_users_missing_value = district_txn_and_users.isna().sum()
district_txn_and_users_missing_value
# Out:
# Missing values in District_Txn and Users dataset:
# State                0
# Year                 0
# Quarter              0
# District             0
# Code                28
# Transactions         0
# Amount (INR)         0
# ATV (INR)            4
# Registered Users     0
# App Opens            0
# dtype: int64

# %%
# Q-1.3.1
# Identify missing value for dataset5
print("Missing values in District Demographics dataset:")
district_demographics_missing_value = district_demographics.isna().sum()
district_demographics_missing_value
# Out:
# Missing values in District Demographics dataset:
# State             0
# District          0
# Headquarters      0
# Population        0
# Area (sq km)      0
# Density           0
# Code              0
# Alternate Name    0
# dtype: int64

# %%
#Q-1.3.2 Calculate the percentage of missing values for each column with missing values
print("Percentage of missing values in State_Txn and Users dataset:")
state_txn_users.isna().mean() * 100
# Out:
# Percentage of missing values in State_Txn and Users dataset:
# State               0.000000
# Year                0.000000
# Quarter             0.000000
# Transactions        0.000000
# Amount (INR)        0.198413
# ATV (INR)           0.000000
# Registered Users    0.000000
# App Opens           0.000000
# dtype: float64

# %%
print("Percentage of missing values in State_TxnSplit dataset:")
state_txn_split.isna().mean() * 100
# Out:
# Percentage of missing values in State_TxnSplit dataset:
# State               0.0
# Year                0.0
# Quarter             0.0
# Transaction Type    0.0
# Transactions        0.0
# Amount (INR)        0.0
# ATV (INR)           0.0
# dtype: float64

# %%
print("Percentage of missing values in State_DeviceData dataset:")
state_device_data.isna().mean() * 100
# Out:
# Percentage of missing values in State_DeviceData dataset:
# State               0.0
# Year                0.0
# Quarter             0.0
# Brand               0.0
# Registered Users    0.0
# Percentage          0.0
# dtype: float64

# %%
print("Percentage of missing values in District_Txn and Users dataset:")
district_txn_and_users.isna().mean() * 100
# Out:
# Percentage of missing values in District_Txn and Users dataset:
# State               0.000000
# Year                0.000000
# Quarter             0.000000
# District            0.000000
# Code                0.273224
# Transactions        0.000000
# Amount (INR)        0.000000
# ATV (INR)           0.039032
# Registered Users    0.000000
# App Opens           0.000000
# dtype: float64

# %%
print("Percentage of missing values in District Demographics dataset:")
district_demographics.isna().mean() * 100
# Out:
# Percentage of missing values in District Demographics dataset:
# State             0.0
# District          0.0
# Headquarters      0.0
# Population        0.0
# Area (sq km)      0.0
# Density           0.0
# Code              0.0
# Alternate Name    0.0
# dtype: float64

# %%
# Q-1.3.3 Highlight the column with the highest percentage of missing values in each dataset.
print("Column with the highest percentage of missing values in State_Txn and Users dataset:")
print(state_txn_users.isna().mean().idxmax(), ":", state_txn_users.isna().mean().max() * 100)
# Out:
# Column with the highest percentage of missing values in State_Txn and Users dataset:
# Amount (INR) : 0.1984126984126984

# %%
print("Column with the highest percentage of missing values in State_TxnSplit dataset:")
print(state_txn_split.isna().mean().idxmax(), ":", state_txn_split.isna().mean().max() * 100)
# Out:
# Column with the highest percentage of missing values in State_TxnSplit dataset:
# State : 0.0

# %%
print("Column with the highest percentage of missing values in State_DeviceData dataset:")
print(state_device_data.isna().mean().idxmax(), ":", state_device_data.isna().mean().max() * 100)
# Out:
# Column with the highest percentage of missing values in State_DeviceData dataset:
# State : 0.0

# %%
print("Column with the highest percentage of missing values in District_Txn and Users dataset:")
print(district_txn_and_users.isna().mean().idxmax(), ":", district_txn_and_users.isna().mean().max() * 100)
# Out:
# Column with the highest percentage of missing values in District_Txn and Users dataset:
# Code : 0.273224043715847

# %%
print("Column with the highest percentage of missing values in District Demographics dataset:")
print(district_demographics.isna().mean().idxmax(), ":", district_demographics.isna().mean().max() * 100)
# Out:
# Column with the highest percentage of missing values in District Demographics dataset:
# State : 0.0

# %%
# Q-1.4 Calculate the total number of states and the total number of districts
state_list = district_txn_and_users['State'].unique().tolist()
total_number_of_state = len(state_list)
print("Total number of state :",total_number_of_state)
district_list = district_txn_and_users['District'].unique().tolist()
total_number_of_district = len(district_list)
print("Total number of District :",total_number_of_district)
# Out:
# Total number of state : 36
# Total number of District : 723

# %%
# Q-1.4.2 Identify the state with the highest number of districts

district_counts = district_demographics['State'].value_counts()
district_counts
# Out:
# State
# Uttar Pradesh                           75
# Madhya Pradesh                          55
# Tamil Nadu                              38
# Bihar                                   38
# Maharashtra                             36
# Assam                                   34
# Rajasthan                               33
# Telangana                               33
# Gujarat                                 33
# Karnataka                               31
# Odisha                                  30
# Chhattisgarh                            28
# Arunachal Pradesh                       25
# Jharkhand                               24
# West Bengal                             23
# Punjab                                  23
# Haryana                                 22
# Jammu & Kashmir                         20
# Manipur                                 16
# Kerala                                  14
# Uttarakhand                             13
# Andhra Pradesh                          13
# ...

# %%
state_with_most_districts = district_counts.idxmax()

print("State with the highest number of districts:", state_with_most_districts)
print("Number of districts in", state_with_most_districts, ":", district_counts.max())
# Out:
# State with the highest number of districts: Uttar Pradesh
# Number of districts in Uttar Pradesh : 75

# %%
state_txn_users.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'Transactions', 'Amount (INR)', 'ATV (INR)',
#        'Registered Users', 'App Opens'],
#       dtype='object')

# %%
# Q-2.1.1 Calculate the total number of transactions and total transaction amount for each state over the years.

total_number_of_transaction = state_txn_users.groupby(["State","Year"]).agg({
    "Transactions": "sum",
    "Amount (INR)": "sum"
}).reset_index()
print("Total transactions and transaction amount for each state over the years:")
total_number_of_transaction
# Out:
# Total transactions and transaction amount for each state over the years:
#                          State  Year  Transactions  Amount (INR)
# 0    Andaman & Nicobar Islands  2018         58021  1.890761e+08
# 1    Andaman & Nicobar Islands  2019        133104  4.734648e+08
# 2    Andaman & Nicobar Islands  2020        446274  1.296423e+09
# 3    Andaman & Nicobar Islands  2021        586166  1.682854e+09
# 4               Andhra Pradesh  2018      77779112  1.220720e+11
# ..                         ...   ...           ...           ...
# 139                Uttarakhand  2021      44608834  7.727901e+10
# 140                West Bengal  2018     120011635  1.115887e+11
# 141                West Bengal  2019     257900590  2.660145e+11
# 142                West Bengal  2020     304222327  5.527316e+11
# 143                West Bengal  2021     260151489  5.223720e+11
#
# [144 rows x 4 columns]

# %%
# Q-2.1.2 Identify the top 5 states with the highest transaction volumes and the top 5 states with the lowest transaction volumes

state_total_txn = state_txn_users.groupby('State')['Transactions'].sum().reset_index()
state_total_txn = state_total_txn.sort_values(by='Transactions', ascending=False)
#Top 5 states with the Highest transaction volume
top_5_states_highest_txn = state_total_txn.head(5)
print("Top 5 states with the highest transaction volumes:")
top_5_states_highest_txn
# Out:
# Top 5 states with the highest transaction volumes:
#              State  Transactions
# 15       Karnataka    2981044533
# 20     Maharashtra    2833670154
# 31       Telangana    2347430243
# 1   Andhra Pradesh    1781091169
# 28       Rajasthan    1382918930

# %%
#Top 5 states with the Lowest transaction volume
top_5_states_lowest_txn = state_total_txn.tail(5)
print("Top 5 states with the lowest transaction volumes:")
top_5_states_lowest_txn
# Out:
# Top 5 states with the lowest transaction volumes:
#                         State  Transactions
# 22                  Meghalaya       5648913
# 23                    Mizoram       2162776
# 17                     Ladakh       1880109
# 0   Andaman & Nicobar Islands       1223565
# 18                Lakshadweep         71610

# %%
# Q-2.2.1 For each state and quarter, determine the most frequent transaction type. 
# Display the result in tabular format.

most_common_txn_type = state_txn_split.groupby(['State', 'Year', 'Quarter', 'Transaction Type']).agg({
    'Transactions': 'sum'
}).reset_index()

most_common_txn_type
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1        Financial Services
# 1     Andaman & Nicobar Islands  2018        1         Merchant payments
# 2     Andaman & Nicobar Islands  2018        1                    Others
# 3     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 4     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2        Financial Services
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2                    Others
# 2512                West Bengal  2021        2     Peer-to-peer payments
# 2513                West Bengal  2021        2  Recharge & bill payments
#
#       Transactions
# 0               33
# 1              298
# 2              256
# ...

# %%
most_common_txn_type = most_common_txn_type.loc[most_common_txn_type.groupby(['State', 'Year', 'Quarter'])
                        ['Transactions'].idxmax()]

print("Most common transaction types in each state and quarter:")
most_common_txn_type
# Out:
# Most common transaction types in each state and quarter:
#                           State  Year  Quarter          Transaction Type  \
# 4     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 9     Andaman & Nicobar Islands  2018        2  Recharge & bill payments
# 14    Andaman & Nicobar Islands  2018        3  Recharge & bill payments
# 19    Andaman & Nicobar Islands  2018        4  Recharge & bill payments
# 24    Andaman & Nicobar Islands  2019        1  Recharge & bill payments
# ...                         ...   ...      ...                       ...
# 2492                West Bengal  2020        2     Peer-to-peer payments
# 2497                West Bengal  2020        3     Peer-to-peer payments
# 2502                West Bengal  2020        4     Peer-to-peer payments
# 2507                West Bengal  2021        1     Peer-to-peer payments
# 2512                West Bengal  2021        2     Peer-to-peer payments
#
#       Transactions
# ...

# %%
# Q-2.3.1 Identify the device brand with the highest number of registered users in each state. Display the result in 
# Tabular format

most_common_device_brand = state_device_data.groupby(['State', 'Brand']).agg({
    'Registered Users': 'sum'
}).reset_index()

most_common_device_brand
# Out:
#                          State     Brand  Registered Users
# 0    Andaman & Nicobar Islands     Apple              9334
# 1    Andaman & Nicobar Islands    Huawei             11497
# 2    Andaman & Nicobar Islands    Lenovo              5362
# 3    Andaman & Nicobar Islands  Motorola              9491
# 4    Andaman & Nicobar Islands   OnePlus             15397
# ..                         ...       ...               ...
# 443                West Bengal    Others          17526532
# 444                West Bengal    Realme           9322038
# 445                West Bengal   Samsung          30516315
# 446                West Bengal      Vivo          18755122
# 447                West Bengal    Xiaomi          38265764
#
# [448 rows x 3 columns]

# %%
most_common_device_brand = most_common_device_brand.loc[most_common_device_brand.groupby('State')
                            ['Registered Users'].idxmax()]
print("Device brand with the highest number of registered users in each state:")
most_common_device_brand
# Out:
# Device brand with the highest number of registered users in each state:
#                                     State    Brand  Registered Users
# 11              Andaman & Nicobar Islands   Xiaomi             97889
# 22                         Andhra Pradesh   Xiaomi          40061549
# 34                      Arunachal Pradesh   Xiaomi            437803
# 46                                  Assam   Xiaomi           6979357
# 60                                  Bihar   Xiaomi          33721314
# 73                             Chandigarh   Xiaomi            896628
# 85                           Chhattisgarh   Xiaomi           8763373
# 98   Dadra & Nagar Haveli and Daman & Diu   Xiaomi            638834
# 109                                 Delhi   Xiaomi          24114984
# 120                                   Goa   Xiaomi           1208672
# 131                               Gujarat   Xiaomi          28942157
# 143                               Haryana   Xiaomi          21102142
# ...

# %%
# Q-2.4.1 For each state, identify the district with the highest population. Display the result in Tabular format.

top_district_per_state_poplulation = district_demographics.loc[district_demographics.groupby('State')
                                    ['Population'].idxmax(),['State', 'District', 'Population']]
print("District with the highest population for each state:")
top_district_per_state_poplulation = top_district_per_state_poplulation.sort_values(by='Population',ascending = False)
top_district_per_state_poplulation
# Out:
# District with the highest population for each state:
#                                     State                District  Population
# 691                           West Bengal       North 24 Parganas    10082852
# 235                             Karnataka         Bangalore Urban     9588910
# 356                           Maharashtra                    Pune     9426959
# 140                               Gujarat               Ahmedabad     7208200
# 509                            Tamil Nadu                 Chennai     7139882
# 489                             Rajasthan                  Jaipur     6663971
# 588                         Uttar Pradesh               Allahabad     5959798
# 97                                  Bihar                   Patna     5772804
# 2                          Andhra Pradesh           East Godavari     5151549
# 270                                Kerala              Malappuram     4110956
# ...

# %%
# Q-2.4.2 Create a column chart depicting the district with the highest population for each state.

import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(max_population_districts['State'], max_population_districts['Population'], color='skyblue')

plt.xticks(rotation=90)  # Rotate district names if too long
plt.xlabel('State')
plt.ylabel('Population')
plt.title('District with the Highest Population for Each State')
plt.tight_layout()
plt.show()

# %%
# Q-2.5.1 Compute the average transaction value for each state. Display the result in a tabular format.

calculate_ATV_state = state_txn_users.groupby('State')['ATV (INR)'].mean().round(2)
calculate_ATV_state = calculate_ATV_state.reset_index().sort_values(by="ATV (INR)", ascending=False)
calculate_ATV_state
# Out:
#                                    State  ATV (INR)
# 17                                Ladakh    3408.22
# 0              Andaman & Nicobar Islands    3159.27
# 23                               Mizoram    2927.52
# 18                           Lakshadweep    2776.12
# 2                      Arunachal Pradesh    2638.32
# 21                               Manipur    2621.23
# 24                              Nagaland    2609.94
# 13                       Jammu & Kashmir    2508.51
# 5                             Chandigarh    2113.80
# 29                                Sikkim    2087.84
# 27                                Punjab    2085.23
# 22                             Meghalaya    2056.28
# 4                                  Bihar    2023.32
# 3                                  Assam    2008.50
# 26                            Puducherry    1927.61
# 9                                    Goa    1895.26
# 30                            Tamil Nadu    1861.37
# ...

# %%
# Q-2.5.2 Identify the top 5 states with the highest ATV and the top 5 states with the Lowest ATV. Display the results.
# Highest ATV
print("Top 5 states with the highest average transaction value (ATV):")
calculate_ATV_state.head(5)
# Out:
# Top 5 states with the highest average transaction value (ATV):
#                         State  ATV (INR)
# 17                     Ladakh    3408.22
# 0   Andaman & Nicobar Islands    3159.27
# 23                    Mizoram    2927.52
# 18                Lakshadweep    2776.12
# 2           Arunachal Pradesh    2638.32

# %%
# Lowest ATV
print("Top 5 states with the lowest average transaction value (ATV):")
calculate_ATV_state.tail(5)
# Out:
# Top 5 states with the lowest average transaction value (ATV):
#                                    State  ATV (INR)
# 15                             Karnataka    1517.39
# 20                           Maharashtra    1516.36
# 7   Dadra & Nagar Haveli and Daman & Diu    1487.40
# 25                                Odisha    1428.14
# 35                           West Bengal    1373.60

# %%
# Q-2.6.1 Calculate the total number of app opens over the year and quarters for each state. Display the result in 
# Tabular format.

calculate_app_opens = state_txn_users.groupby(['State', 'Year', 'Quarter'])['App Opens'].sum()
calculate_app_opens = calculate_app_opens.reset_index()
print("Total number of app opens over the years and quarters for each state:")
calculate_app_opens
# Out:
# Total number of app opens over the years and quarters for each state:
#                          State  Year  Quarter  App Opens
# 0    Andaman & Nicobar Islands  2018        1          0
# 1    Andaman & Nicobar Islands  2018        2          0
# 2    Andaman & Nicobar Islands  2018        3          0
# 3    Andaman & Nicobar Islands  2018        4          0
# 4    Andaman & Nicobar Islands  2019        1          0
# ..                         ...   ...      ...        ...
# 499                West Bengal  2020        2  198589332
# 500                West Bengal  2020        3  246554831
# 501                West Bengal  2020        4  291721919
# 502                West Bengal  2021        1  316832674
# 503                West Bengal  2021        2  275341466
#
# [504 rows x 4 columns]

# %%
# Identify trends in app usage by creating a line plot showing the number of app opens over time for a Selected state.
# Select a state for visualization
selected_state = 'Delhi'  

# Filter data for the selected state
app_opens_selected_state = calculate_app_opens[calculate_app_opens['State'] == selected_state]
app_opens_selected_state
# Out:
#      State  Year  Quarter  App Opens
# 112  Delhi  2018        1          0
# 113  Delhi  2018        2          0
# 114  Delhi  2018        3          0
# 115  Delhi  2018        4          0
# 116  Delhi  2019        1          0
# 117  Delhi  2019        2   43731570
# 118  Delhi  2019        3  163381027
# 119  Delhi  2019        4  172682671
# 120  Delhi  2020        1  178263986
# 121  Delhi  2020        2  142852253
# 122  Delhi  2020        3  190025029
# 123  Delhi  2020        4  243433752
# 124  Delhi  2021        1  281201600
# 125  Delhi  2021        2  164997774

# %%
app_opens_selected_state.loc[:, 'Year_Quarter'] = (
    app_opens_selected_state['Year'].astype('Int64').astype(str)
    + ' Q' +
    app_opens_selected_state['Quarter'].astype('Int64').astype(str)
)
app_opens_selected_state
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2188\2022208630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app_opens_selected_state.loc[:, 'Year_Quarter'] = (
#      State  Year  Quarter  App Opens Year_Quarter
# 112  Delhi  2018        1          0      2018 Q1
# 113  Delhi  2018        2          0      2018 Q2
# 114  Delhi  2018        3          0      2018 Q3
# 115  Delhi  2018        4          0      2018 Q4
# 116  Delhi  2019        1          0      2019 Q1
# 117  Delhi  2019        2   43731570      2019 Q2
# 118  Delhi  2019        3  163381027      2019 Q3
# 119  Delhi  2019        4  172682671      2019 Q4
# 120  Delhi  2020        1  178263986      2020 Q1
# 121  Delhi  2020        2  142852253      2020 Q2
# ...

# %%
plt.figure(figsize=(12,8))

plt.plot(app_opens_selected_state['Year_Quarter'], app_opens_selected_state['App Opens'], marker='o')

plt.title(f'App Opens Over Time for {selected_state}', color='red')
plt.xlabel('Year and Quarter')
plt.ylabel('App Opens')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Q-2.7.1 Create a bar chart showing the distribution of different transaction types for each state for the most recent 
# quarter in the dataset.

most_recent_quarter = (
    state_txn_split[['Year','Quarter']].drop_duplicates().nlargest(1, ['Year','Quarter']).iloc[0]
)
most_recent_quarter
# Out:
# Year       2021
# Quarter       2
# Name: 65, dtype: int64

# %%
most_recent_txn_types = (
    state_txn_split[(state_txn_split['Year'] == most_recent_quarter['Year']) 
    & (state_txn_split['Quarter'] == most_recent_quarter['Quarter'])]
)
most_recent_txn_types
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 65    Andaman & Nicobar Islands  2021        2     Peer-to-peer payments
# 66    Andaman & Nicobar Islands  2021        2  Recharge & bill payments
# 67    Andaman & Nicobar Islands  2021        2         Merchant payments
# 68    Andaman & Nicobar Islands  2021        2        Financial Services
# 69    Andaman & Nicobar Islands  2021        2                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
txn_type_distribution = most_recent_txn_types.groupby('Transaction Type').agg({
    'Transactions': 'sum'
}).reset_index()

txn_type_distribution
# Out:
#            Transaction Type  Transactions
# 0        Financial Services       3397356
# 1         Merchant payments    1499624295
# 2                    Others       9061701
# 3     Peer-to-peer payments    1744265068
# 4  Recharge & bill payments     685022045

# %%
plt.figure(figsize=(10,6))
plt.bar(txn_type_distribution['Transaction Type'], txn_type_distribution['Transactions'], color = "lightgreen")
plt.xlabel('Transaction Type')
plt.ylabel('Number of Transactions')
plt.title(f'Distribution of Transaction Types for the Most Recent Quarter ({most_recent_quarter["Year"]} Q{most_recent_quarter["Quarter"]})')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q-2.8.1 Identify the unique mapping between district names and district codes from the dataset.
unique_mapping = district_txn_and_users[['District', 'Code']].drop_duplicates()
print("Unique mapping between district names and district codes:")
unique_mapping
# Out:
# Unique mapping between district names and district codes:
#                         District  Code
# 0                       Nicobars  AN01
# 1       North And Middle Andaman  AN02
# 2                  South Andaman  AN03
# 42                     Anantapur  AP01
# 43                      Chittoor  AP02
# ...                          ...   ...
# 9944             Purba Bardhaman  WB19
# 9945             Purba Medinipur  WB20
# 9946                     Purulia  WB21
# 9947  South Twenty Four Parganas  WB22
# 9948              Uttar Dinajpur  WB23
#
# [732 rows x 2 columns]

# %%
# Q-2.8.2 Create a csv file containing the unique district name and district code mapping.

from io import StringIO

#Create a CSV in memory
csv_buffer = StringIO()
unique_mapping.to_csv(csv_buffer, index=False)

# Move cursor to start so you can read it
csv_buffer.seek(0)

# Display the CSV content
print(csv_buffer.getvalue())
# Out:
# District,Code
# Nicobars,AN01
# North And Middle Andaman,AN02
# South Andaman,AN03
# Anantapur,AP01
# Chittoor,AP02
# East Godavari,AP03
# Guntur,AP04
# Krishna,AP05
# Kurnool,AP06
# Prakasam,AP07
# Spsr Nellore,AP08
# Srikakulam,AP09
# Visakhapatnam,AP10
# Vizianagaram,AP11
# West Godavari,AP12
# Ysr,AP13
# Anjaw,AR01
# Changlang,AR02
# Dibang Valley,AR21
# East Kameng,AR03
# East Siang,AR04
# Kamle,AR05
# Kra Daadi,AR06
# Kurung Kumey,AR07
# Lepa Rada,AR08
# Lohit,AR09
# Longding,AR10
# Lower Dibang Valley,AR11
# Lower Siang,AR12
# Lower Subansiri,AR13
# Namsai,AR14
# Pakke Kessang,AR15
# Papum Pare,AR16
# Shi Yomi,AR17
# Siang,AR18
# Tawang,AR19
# Tirap,AR20
# Upper Siang,AR22
# Upper Subansiri,AR23
# West Kameng,AR24
# West Siang,AR25
# Baksa,AS02
# Barpeta,AS03
# Biswanath,AS04
# Bongaigaon,AS05
# Cachar,AS06
# Charaideo,AS07
# Chirang,AS08
# Darrang,AS09
# Dhemaji,AS10
# Dhubri,AS11
# Dibrugarh,AS12
# Dima Hasao,AS13
# Goalpara,AS14
# Golaghat,AS15
# Hailakandi,AS16
# ...

# %%
# Q-2.8.3 Export the CSV file.

unique_mapping.to_csv("district_unique_mapping.csv", index=False)

print("CSV file created: district_unique_mapping.csv")
# Out:
# CSV file created: district_unique_mapping.csv

# %%
# Q-3.1.1 For each state, calculate the total number of transactions, total transaction amount and total registered 
# users by summing up the values from the district level data.

district_agg = district_txn_and_users.groupby('State')[['Transactions', 'Amount (INR)', 'Registered Users']].sum().reset_index()

print("Aggregated values at the district level:")
# Display the result
district_agg
# Out:
# Aggregated values at the district level:
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565  3.641818e+09
# 1                         Andhra Pradesh    1781091169  3.860292e+12
# 2                      Arunachal Pradesh       8043799  2.225183e+10
# 3                                  Assam     123577981  2.814087e+11
# 4                                  Bihar     713643889  1.639579e+12
# 5                             Chandigarh      25516542  5.371208e+10
# 6                           Chhattisgarh     241908549  4.156353e+11
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# 8                                  Delhi    1011031124  1.649942e+12
# 9                                    Goa      24481604  4.427187e+10
# 10                               Gujarat     612992823  1.105329e+12
# 11                               Haryana     567751410  1.059832e+12
# ...

# %%
# Q-3.1.2 Compare the results with the corresponding values at the state level to ensure they match. 

state_agg = state_txn_users.groupby('State')[['Transactions', 'Amount (INR)', 'Registered Users']].sum().reset_index()

print("Aggregated values at the State level:")
# Display the result
state_agg
# Out:
# Aggregated values at the State level:
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565  3.641818e+09
# 1                         Andhra Pradesh    1781091169  3.187847e+12
# 2                      Arunachal Pradesh       8043799  2.225183e+10
# 3                                  Assam     123577981  2.814087e+11
# 4                                  Bihar     713643889  1.639579e+12
# 5                             Chandigarh      25516542  5.371208e+10
# 6                           Chhattisgarh     241908549  4.156353e+11
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# 8                                  Delhi    1011031124  1.649942e+12
# 9                                    Goa      24481604  4.427187e+10
# 10                               Gujarat     612992823  1.105329e+12
# 11                               Haryana     567751410  1.059832e+12
# ...

# %%
comparison = pd.merge(state_agg, district_agg, on='State', suffixes=('_state', '_district'))
comparison
# Out:
#                                    State  Transactions_state  \
# 0              Andaman & Nicobar Islands             1223565
# 1                         Andhra Pradesh          1781091169
# 2                      Arunachal Pradesh             8043799
# 3                                  Assam           123577981
# 4                                  Bihar           713643889
# 5                             Chandigarh            25516542
# 6                           Chhattisgarh           241908549
# 7   Dadra & Nagar Haveli and Daman & Diu            12462185
# 8                                  Delhi          1011031124
# 9                                    Goa            24481604
# 10                               Gujarat           612992823
# 11                               Haryana           567751410
# 12                      Himachal Pradesh            52987445
# 13                       Jammu & Kashmir            45053328
# ...

# %%
comparison['Transactions_Match'] = comparison['Transactions_state'] == comparison['Transactions_district']
comparison['Amount_Match'] = comparison['Amount (INR)_state'] == comparison['Amount (INR)_district']
comparison['Users_Match'] = comparison['Registered Users_state'] == comparison['Registered Users_district']

comparison
# Out:
#                                    State  Transactions_state  \
# 0              Andaman & Nicobar Islands             1223565
# 1                         Andhra Pradesh          1781091169
# 2                      Arunachal Pradesh             8043799
# 3                                  Assam           123577981
# 4                                  Bihar           713643889
# 5                             Chandigarh            25516542
# 6                           Chhattisgarh           241908549
# 7   Dadra & Nagar Haveli and Daman & Diu            12462185
# 8                                  Delhi          1011031124
# 9                                    Goa            24481604
# 10                               Gujarat           612992823
# 11                               Haryana           567751410
# 12                      Himachal Pradesh            52987445
# 13                       Jammu & Kashmir            45053328
# ...

# %%
# Q-3.1.3 Display the discrepancies found between the district-level and state-level data.

discrepancies = comparison[(comparison['Transactions_Match'] == False) | (comparison['Amount_Match'] == False) | (comparison['Users_Match'] == False)]

print("Discrepancies found between district-level and state-level data:")
discrepancies
# Out:
# Discrepancies found between district-level and state-level data:
#                                    State  Transactions_state  \
# 0              Andaman & Nicobar Islands             1223565
# 1                         Andhra Pradesh          1781091169
# 2                      Arunachal Pradesh             8043799
# 3                                  Assam           123577981
# 4                                  Bihar           713643889
# 5                             Chandigarh            25516542
# 6                           Chhattisgarh           241908549
# 7   Dadra & Nagar Haveli and Daman & Diu            12462185
# 8                                  Delhi          1011031124
# 9                                    Goa            24481604
# 10                               Gujarat           612992823
# 11                               Haryana           567751410
# 12                      Himachal Pradesh            52987445
# ...

# %%
# Q-4.1.1 Merge the State_Txn and Users dataset with district demographics dataset to calculate the ratio of registered
# users to the population for each state. Display the results in the tabular format.

state_population = district_demographics.groupby('State')['Population'].sum().reset_index()
state_population
# Out:
#                                    State  Population
# 0              Andaman & Nicobar Islands      380581
# 1                         Andhra Pradesh    49378776
# 2                      Arunachal Pradesh     1606047
# 3                                  Assam    34461385
# 4                                  Bihar   103817951
# 5                             Chandigarh     1055450
# 6                           Chhattisgarh    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu      586956
# 8                                  Delhi    16787941
# 9                                    Goa     1457723
# 10                               Gujarat    65930328
# 11                               Haryana    25855357
# 12                      Himachal Pradesh     6856509
# 13                       Jammu & Kashmir    12258093
# 14                             Jharkhand    32966238
# 15                             Karnataka    60965960
# 16                                Kerala    33387677
# ...

# %%
state_users_population = pd.merge(state_txn_users.groupby('State')['Registered Users'].sum().reset_index(), state_population, on='State')
state_users_population
# Out:
#                                    State  Registered Users  Population
# 0              Andaman & Nicobar Islands            408396      380581
# 1                         Andhra Pradesh         158007957    49378776
# 2                      Arunachal Pradesh           1862214     1606047
# 3                                  Assam          26860751    34461385
# 4                                  Bihar         115284760   103817951
# 5                             Chandigarh           3801466     1055450
# 6                           Chhattisgarh          37448388    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu           2701112      586956
# 8                                  Delhi          95374654    16787941
# 9                                    Goa           4755320     1457723
# 10                               Gujarat         126380032    65930328
# 11                               Haryana          85564119    25855357
# ...

# %%
state_users_population['Users_to_Population_Ratio'] = (
                    state_users_population['Registered Users'] / state_users_population['Population']
)
print("Ratio of registered users to population for each state:")
state_users_population
# Out:
# Ratio of registered users to population for each state:
#                                    State  Registered Users  Population  \
# 0              Andaman & Nicobar Islands            408396      380581
# 1                         Andhra Pradesh         158007957    49378776
# 2                      Arunachal Pradesh           1862214     1606047
# 3                                  Assam          26860751    34461385
# 4                                  Bihar         115284760   103817951
# 5                             Chandigarh           3801466     1055450
# 6                           Chhattisgarh          37448388    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu           2701112      586956
# 8                                  Delhi          95374654    16787941
# 9                                    Goa           4755320     1457723
# 10                               Gujarat         126380032    65930328
# ...

# %%
# Q-4.1.2 Create a column chart depicting the ratio of users to population by state.

plt.figure(figsize=(12, 8))
plt.bar(state_users_population['State'], state_users_population['Users_to_Population_Ratio'], color="#27f5e7")
plt.xlabel('Users to Population Ratio')
plt.ylabel('State')
plt.title('Ratio of Users to Population by State')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %%
# Q-4.2.1 Merge the District_Txn and Users dataset with the District Demographics dataset.

district_txn_and_users
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
district_demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
district_merged = pd.merge(district_txn_and_users, district_demographics, on=['State', 'District', 'Code'])

print("Merged district-level dataset:")
district_merged.head()
# Out:
# Merged district-level dataset:
#                        State  Year  Quarter       District  Code  \
# 0  Andaman & Nicobar Islands  2018        1  South Andaman  AN03
# 1  Andaman & Nicobar Islands  2018        2  South Andaman  AN03
# 2  Andaman & Nicobar Islands  2018        3  South Andaman  AN03
# 3  Andaman & Nicobar Islands  2018        4  South Andaman  AN03
# 4  Andaman & Nicobar Islands  2019        1  South Andaman  AN03
#
#    Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# 0          5688  1.256025e+07  2208.201361              5846          0
# 1          9395  2.394824e+07  2549.040502              8143          0
# 2         13511  4.426811e+07  3276.449742             10474          0
# 3         20136  7.541184e+07  3745.125189             13133          0
# 4         25683  8.550197e+07  3329.127142             15961          0
#
#   Headquarters  Population  Area (sq km)  Density Alternate Name
# ...

# %%
# Q-4.2.2 Calculate the correlation between population density and transaction volume.

correlation = district_merged[['Density', 'Transactions']].corr()
correlation
# Out:
#                Density  Transactions
# Density       1.000000      0.307704
# Transactions  0.307704      1.000000

# %%
correlation = district_merged[['Density', 'Transactions']].corr().iloc[0, 1]

print(f"Correlation between population density and transaction volume: {correlation}")
# Out:
# Correlation between population density and transaction volume: 0.30770410875592874

# %%
# Q-4.2.3 Create a scatter plot to visualize the correlation between population density and transaction volume.

plt.figure(figsize=(12, 8))
plt.scatter(district_merged['Density'], district_merged['Transactions'], color = '#09e075')
plt.xlabel('Population Density')
plt.ylabel('Transaction Volume')
plt.title('Correlation between Population Density and Transaction Volume')
plt.show()

# %%
# Q-4.3.1 Merge relevant datasets to calculate the average transaction amount per user for each state.
# Display the result in the tabular format.

state_transactions = state_txn_users.groupby('State').agg({
    'Amount (INR)': 'sum',
    'Registered Users': 'sum'
}).reset_index()

state_transactions
# Out:
#                                    State  Amount (INR)  Registered Users
# 0              Andaman & Nicobar Islands  3.641818e+09            408396
# 1                         Andhra Pradesh  3.187847e+12         158007957
# 2                      Arunachal Pradesh  2.225183e+10           1862214
# 3                                  Assam  2.814087e+11          26860751
# 4                                  Bihar  1.639579e+12         115284760
# 5                             Chandigarh  5.371208e+10           3801466
# 6                           Chhattisgarh  4.156353e+11          37448388
# 7   Dadra & Nagar Haveli and Daman & Diu  1.865878e+10           2701112
# 8                                  Delhi  1.649942e+12          95374654
# 9                                    Goa  4.427187e+10           4755320
# 10                               Gujarat  1.105329e+12         126380032
# 11                               Haryana  1.059832e+12          85564119
# ...

# %%
state_transactions['Avg_Transaction_Amount_Per_User'] = (
    state_transactions['Amount (INR)'] / state_transactions['Registered Users']
)
print("Average transaction amount per user for each state:")
state_transactions
# Out:
# Average transaction amount per user for each state:
#                                    State  Amount (INR)  Registered Users  \
# 0              Andaman & Nicobar Islands  3.641818e+09            408396
# 1                         Andhra Pradesh  3.187847e+12         158007957
# 2                      Arunachal Pradesh  2.225183e+10           1862214
# 3                                  Assam  2.814087e+11          26860751
# 4                                  Bihar  1.639579e+12         115284760
# 5                             Chandigarh  5.371208e+10           3801466
# 6                           Chhattisgarh  4.156353e+11          37448388
# 7   Dadra & Nagar Haveli and Daman & Diu  1.865878e+10           2701112
# 8                                  Delhi  1.649942e+12          95374654
# 9                                    Goa  4.427187e+10           4755320
# 10                               Gujarat  1.105329e+12         126380032
# ...

# %%
# Q-4.3.2 Identify the top 5 states with the highest average transaction amount per user and the top 5 states with the 
# lowest average transaction amount per user. Display the results.

avg_transaction_amnt_sort = state_transactions.sort_values(by='Avg_Transaction_Amount_Per_User', ascending=False)
avg_transaction_amnt_sort
# Out:
#                                    State  Amount (INR)  Registered Users  \
# 31                             Telangana  4.574246e+12         149224214
# 15                             Karnataka  4.361396e+12         203098564
# 1                         Andhra Pradesh  3.187847e+12         158007957
# 28                             Rajasthan  2.625584e+12         149770064
# 8                                  Delhi  1.649942e+12          95374654
# 21                               Manipur  3.579325e+10           2317734
# 19                        Madhya Pradesh  1.915101e+12         125339823
# 25                                Odisha  1.220615e+12          80404103
# 4                                  Bihar  1.639579e+12         115284760
# 5                             Chandigarh  5.371208e+10           3801466
# 20                           Maharashtra  4.290995e+12         315783658
# 11                               Haryana  1.059832e+12          85564119
# ...

# %%
print("Top 5 States with the highest average transaction amount per user")
top_5_highest_transaction_amnt_per_user = avg_transaction_amnt_sort.head(5)
top_5_highest_transaction_amnt_per_user
# Out:
# Top 5 States with the highest average transaction amount per user
#              State  Amount (INR)  Registered Users  \
# 31       Telangana  4.574246e+12         149224214
# 15       Karnataka  4.361396e+12         203098564
# 1   Andhra Pradesh  3.187847e+12         158007957
# 28       Rajasthan  2.625584e+12         149770064
# 8            Delhi  1.649942e+12          95374654
#
#     Avg_Transaction_Amount_Per_User
# 31                     30653.509622
# 15                     21474.282206
# 1                      20175.233763
# 28                     17530.768707
# 8                      17299.587909

# %%
print("Top 5 States with the Lowest average transaction amount per user")
top_5_lowest_transaction_amnt_per_user = avg_transaction_amnt_sort.tail(5)
top_5_lowest_transaction_amnt_per_user
# Out:
# Top 5 States with the Lowest average transaction amount per user
#                                    State  Amount (INR)  Registered Users  \
# 12                      Himachal Pradesh  9.786546e+10          13373980
# 16                                Kerala  3.729599e+11          51267042
# 7   Dadra & Nagar Haveli and Daman & Diu  1.865878e+10           2701112
# 32                               Tripura  2.097051e+10           3661575
# 18                           Lakshadweep  1.921587e+08             34223
#
#     Avg_Transaction_Amount_Per_User
# 12                      7317.601442
# 16                      7274.846690
# 7                       6907.815954
# 32                      5727.184275
# 18                      5614.898889

# %%
# Q-4.4.1 Merge the state_DeviceData dataset with the State_Txn and Users dataset.

state_device_data
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
state_txn_users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
state_dvc_and_state_txn_mrg = pd.merge(state_device_data,state_txn_users[['State', 'Registered Users']].drop_duplicates(), 
                                on='State')
print("Merged state-level device data:")
state_dvc_and_state_txn_mrg
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 49
# Merged state-level device data:
#                            State  Year  Quarter   Brand  Registered Users_x  \
# 0      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 1      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 2      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 3      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 4      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# ...                          ...   ...      ...     ...                 ...
# 77611                West Bengal  2021        2  Others             1928653
# 77612                West Bengal  2021        2  Others             1928653
# 77613                West Bengal  2021        2  Others             1928653
# 77614                West Bengal  2021        2  Others             1928653
# ...

# %%
# Q-4.4.2 Calculate the ratio of users using each device brand to the total number of registered users in each stat.
# Display the results in Tabular format.

state_dvc_and_state_txn_mrg['Brand_Usage_Ratio'] =(
    state_dvc_and_state_txn_mrg['Registered Users_x'] / state_dvc_and_state_txn_mrg['Registered Users_y']
)
print("Device brand usage ratio for each state:")
state_dvc_and_state_txn_mrg[['State', 'Brand', 'Registered Users_x', 'Registered Users_y', 'Brand_Usage_Ratio']]
# Out:
# Device brand usage ratio for each state:
#                            State   Brand  Registered Users_x  \
# 0      Andaman & Nicobar Islands  Xiaomi                1665
# 1      Andaman & Nicobar Islands  Xiaomi                1665
# 2      Andaman & Nicobar Islands  Xiaomi                1665
# 3      Andaman & Nicobar Islands  Xiaomi                1665
# 4      Andaman & Nicobar Islands  Xiaomi                1665
# ...                          ...     ...                 ...
# 77611                West Bengal  Others             1928653
# 77612                West Bengal  Others             1928653
# 77613                West Bengal  Others             1928653
# 77614                West Bengal  Others             1928653
# 77615                West Bengal  Others             1928653
#
#        Registered Users_y  Brand_Usage_Ratio
# 0                    6740           0.247033
# 1                    9405           0.177033
# 2                   12149           0.137048
# ...

# %%
# Q-4.4.3 Create a bar chart depicting the device brand usage ratio for each state.

plt.figure(figsize=(12, 8))

# Example for a single state
selected_state = 'Delhi'  # Example selected state
state_data = state_dvc_and_state_txn_mrg[state_dvc_and_state_txn_mrg['State'] == selected_state]

plt.bar(state_data['Brand'], state_data['Brand_Usage_Ratio'], color="#8eed11")
plt.xlabel('Device Brand')
plt.ylabel('Usage Ratio')
plt.title(f'Device Brand Usage Ratio for {selected_state}')
plt.xticks(rotation=45)
plt.show()

# %%
# Q-5.1.1 Create a line plot showing the total number of transactions and the total transaction amount over time
# (years and quarters) for a selected state.

# Select a state for visualization
selected_state = 'Delhi'  # Example selected state

# Filter data for the selected state
state_data = state_txn_users[state_txn_users['State'] == selected_state]
state_data
# Out:
#      State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 112  Delhi  2018        1       7122754  1.121150e+10  1574.040576
# 113  Delhi  2018        2       9373723  1.744630e+10  1861.192175
# 114  Delhi  2018        3      18547048  2.737585e+10  1476.021783
# 115  Delhi  2018        4      29187719  3.972286e+10  1360.944225
# 116  Delhi  2019        1      47007327  5.846913e+10  1243.830175
# 117  Delhi  2019        2      57171512  8.170682e+10  1429.152618
# 118  Delhi  2019        3      69537876  1.031968e+11  1484.037448
# 119  Delhi  2019        4      80744997  1.290245e+11  1597.925224
# 120  Delhi  2020        1      81747604  1.336165e+11  1634.501039
# 121  Delhi  2020        2      66042018  1.078734e+11  1633.406148
# 122  Delhi  2020        3      96491861  1.751640e+11  1815.323707
# 123  Delhi  2020        4     120540417  2.162651e+11  1794.129252
# 124  Delhi  2021        1     157359004  2.669283e+11  1696.301694
# ...

# %%
state_data = state_data.copy()
state_data.loc[:, 'Year_Quarter'] = (
    state_data['Year'].astype('Int64').astype(str)
    + ' Q ' +
    state_data['Quarter'].astype('Int64').astype(str)
)

state_data
# Out:
#      State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 112  Delhi  2018        1       7122754  1.121150e+10  1574.040576
# 113  Delhi  2018        2       9373723  1.744630e+10  1861.192175
# 114  Delhi  2018        3      18547048  2.737585e+10  1476.021783
# 115  Delhi  2018        4      29187719  3.972286e+10  1360.944225
# 116  Delhi  2019        1      47007327  5.846913e+10  1243.830175
# 117  Delhi  2019        2      57171512  8.170682e+10  1429.152618
# 118  Delhi  2019        3      69537876  1.031968e+11  1484.037448
# 119  Delhi  2019        4      80744997  1.290245e+11  1597.925224
# 120  Delhi  2020        1      81747604  1.336165e+11  1634.501039
# 121  Delhi  2020        2      66042018  1.078734e+11  1633.406148
# 122  Delhi  2020        3      96491861  1.751640e+11  1815.323707
# 123  Delhi  2020        4     120540417  2.162651e+11  1794.129252
# 124  Delhi  2021        1     157359004  2.669283e+11  1696.301694
# ...

# %%
plt.figure(figsize=(14, 8))
plt.plot(state_data['Year_Quarter'], state_data['Transactions'], marker='o', label='Total Transactions', color="#e431f5")
plt.xlabel('Year and Quarter')
plt.ylabel('Total Transactions')
plt.title(f'Total Transactions Over Time for {selected_state}')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Q-5.2.1 Create a pie chart showing the distribution of different transaction types for a selected state
# and Quarter.

selected_state = 'Delhi' 
selected_year = 2021
selected_quarter = 1

# Filter data for the selected state, year, and quarter
state_quarter_data = state_txn_split[(state_txn_split['State'] == selected_state) &
                                     (state_txn_split['Year'] == selected_year) &
                                     (state_txn_split['Quarter'] == selected_quarter)]

state_quarter_data
# Out:
#      State  Year  Quarter          Transaction Type  Transactions  \
# 620  Delhi  2021        1         Merchant payments      72615587
# 621  Delhi  2021        1     Peer-to-peer payments      61957428
# 622  Delhi  2021        1  Recharge & bill payments      21164274
# 623  Delhi  2021        1        Financial Services        153039
# 624  Delhi  2021        1                    Others       1468676
#
#      Amount (INR)    ATV (INR)
# 620  3.986153e+10   548.939068
# 621  2.108236e+11  3402.716325
# 622  1.544741e+10   729.881340
# 623  2.031069e+08  1327.157472
# 624  5.927452e+08   403.591501

# %%
txn_type_distribution = state_quarter_data.groupby('Transaction Type')['Transactions'].sum().reset_index()
txn_type_distribution
# Out:
#            Transaction Type  Transactions
# 0        Financial Services        153039
# 1         Merchant payments      72615587
# 2                    Others       1468676
# 3     Peer-to-peer payments      61957428
# 4  Recharge & bill payments      21164274

# %%
plt.figure(figsize=(6, 4))
plt.pie(txn_type_distribution['Transactions'], labels=txn_type_distribution['Transaction Type'], autopct='%1.1f%%', startangle=140)
plt.title(f'Distribution of Transaction Types for {selected_state} in {selected_year} Q{selected_quarter}')
plt.axis('equal')
plt.show()

# %%
# Q-5.3.1 create a bar plot showing the population density of districts in a selected state.

selected_state = "West Bengal"
state_population_density = district_demographics[district_demographics['State'] == selected_state]

state_population_density
# Out:
#            State           District   Headquarters  Population  Area (sq km)  \
# 674  West Bengal         Alipurduar     Alipurduar     1501983       3136.00
# 675  West Bengal            Bankura        Bankura     3596292       6882.00
# 676  West Bengal  Paschim Bardhaman        Asansol     2882031       1603.00
# 677  West Bengal    Purba Bardhaman      Bardhaman     4835532       5433.00
# 678  West Bengal            Birbhum           Suri     3502387       4545.00
# 679  West Bengal        Cooch Behar    Cooch Behar     2822780       3387.00
# 680  West Bengal   Dakshin Dinajpur      Balurghat     1670931       2183.00
# 681  West Bengal         Darjeeling     Darjeeling     1595181       2093.00
# 682  West Bengal            Hooghly      Chinsurah     5520389       3149.00
# 683  West Bengal             Howrah         Howrah     4841638       1467.00
# 684  West Bengal         Jalpaiguri     Jalpaiguri     3869675       6227.00
# ...

# %%
plt.figure(figsize=(14, 8))
plt.bar(state_population_density['District'], state_population_density['Density'], color="#f5456b")
plt.xlabel('District')
plt.ylabel('Population Density')
plt.title(f'Population Density of Districts in {selected_state}')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Q-6.1.1 Analyze the transaction data to identify any noticeable trends or Patterns.

transaction_trends = state_txn_users.groupby('Year').agg({
    'Transactions': 'sum',
    'Amount (INR)': 'sum'
}).reset_index()

print("Transaction trends over the years:")
transaction_trends
# Out:
# Transaction trends over the years:
#    Year  Transactions  Amount (INR)
# 0  2018    1080202410  1.623045e+12
# 1  2019    4079827215  6.276688e+12
# 2  2020    7973974741  1.464116e+13
# 3  2021    7398955928  1.308826e+13

# %%
transaction_trends_year= transaction_trends['Year'].astype('str')

plt.figure(figsize=(12, 8))
plt.plot(transaction_trends_year, transaction_trends['Transactions'], marker='o', label='Transaction trends over the years', color="#e431f5")
plt.xlabel('Year')
plt.ylabel('Total Transactions')
plt.title(f'Transaction trends over the years')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
transaction_trends_summary = transaction_trends.describe()
print("Summary of transaction trends:")
transaction_trends_summary.drop('Year', axis = 1)
# Out:
# Summary of transaction trends:
#        Transactions  Amount (INR)
# count  4.000000e+00  4.000000e+00
# mean   5.133240e+09  8.907290e+12
# std    3.201043e+09  6.064600e+12
# min    1.080202e+09  1.623045e+12
# 25%    3.329921e+09  5.113277e+12
# 50%    5.739392e+09  9.682476e+12
# 75%    7.542711e+09  1.347649e+13
# max    7.973975e+09  1.464116e+13

# %%
# Q-6.2.1 Find the correlations between demogrphic data (e.g., Population, Density) and 
# Transaction data(e.g. Transaction Volume). Summarize your findings 

merged_data = pd.merge(district_txn_and_users, district_demographics, on=['State', 'District', 'Code'])

merged_data
# Out:
#                           State  Year  Quarter        District  Code  \
# 0     Andaman & Nicobar Islands  2018        1   South Andaman  AN03
# 1     Andaman & Nicobar Islands  2018        2   South Andaman  AN03
# 2     Andaman & Nicobar Islands  2018        3   South Andaman  AN03
# 3     Andaman & Nicobar Islands  2018        4   South Andaman  AN03
# 4     Andaman & Nicobar Islands  2019        1   South Andaman  AN03
# ...                         ...   ...      ...             ...   ...
# 8787                West Bengal  2020        2  Uttar Dinajpur  WB23
# 8788                West Bengal  2020        3  Uttar Dinajpur  WB23
# 8789                West Bengal  2020        4  Uttar Dinajpur  WB23
# 8790                West Bengal  2021        1  Uttar Dinajpur  WB23
# 8791                West Bengal  2021        2  Uttar Dinajpur  WB23
#
#       Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# ...

# %%
correlation_matrix = merged_data[['Population', 'Density', 'Transactions', 'Amount (INR)', 'Registered Users']].corr()

print("Correlation matrix:")
correlation_matrix
# Out:
# Correlation matrix:
#                   Population   Density  Transactions  Amount (INR)  \
# Population          1.000000  0.304296      0.359157      0.350666
# Density             0.304296  1.000000      0.307704      0.336795
# Transactions        0.359157  0.307704      1.000000      0.976292
# Amount (INR)        0.350666  0.336795      0.976292      1.000000
# Registered Users    0.657427  0.301424      0.802563      0.783425
#
#                   Registered Users
# Population                0.657427
# Density                   0.301424
# Transactions              0.802563
# Amount (INR)              0.783425
# Registered Users          1.000000

# %%
# Summarize findings
correlation_summary = correlation_matrix.describe()
print("Summary of correlation findings:")
correlation_summary
# Out:
# Summary of correlation findings:
#        Population   Density  Transactions  Amount (INR)  Registered Users
# count    5.000000  5.000000      5.000000      5.000000          5.000000
# mean     0.534309  0.450044      0.689143      0.689435          0.708968
# std      0.295523  0.307761      0.334042      0.326608          0.258724
# min      0.304296  0.301424      0.307704      0.336795          0.301424
# 25%      0.350666  0.304296      0.359157      0.350666          0.657427
# 50%      0.359157  0.307704      0.802563      0.783425          0.783425
# 75%      0.657427  0.336795      0.976292      0.976292          0.802563
# max      1.000000  1.000000      1.000000      1.000000          1.000000
